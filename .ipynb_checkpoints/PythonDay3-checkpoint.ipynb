# %% [markdown]
# # continue pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
# Add costume column

# %%
df['marks']/10+1.5
# Out:
# 0    7.177
# 1    7.477
# 2    9.188
# 3    8.466
# 4    7.828
# 5    6.455
# 6    8.034
# 7    8.333
# 8    7.175
# 9    9.366
# Name: marks, dtype: float64

# %%
# Add a new column is same like adding in dictonary #if the key is not present it will be added if present it will be replaced
df['cgpa']=df['marks']/10+1.5
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.27   22  7.227
# 1     2     amit    TE  60.27   21  7.527
# 2     3   aniket    BE  77.38   19  9.238
# 3     4  ajinkya    TE  70.16   20  8.516
# 4     5     asha    TE  63.78   20  7.878
# 5     6   ayesha    BE  50.05   20  6.505
# 6     7     amar    BE  65.84   19  8.084
# 7     8    amita    BE  68.83   23  8.383
# 8     9     amol    TE  57.25   20  7.225
# 9    10    anmol    BE  79.16   21  9.416

# %%
# Give 0.5 grace to all student
df['marks']=df['marks']+0.5
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.27   22  7.177
# 1     2     amit    TE  60.27   21  7.477
# 2     3   aniket    BE  77.38   19  9.188
# 3     4  ajinkya    TE  70.16   20  8.466
# 4     5     asha    TE  63.78   20  7.828
# 5     6   ayesha    BE  50.05   20  6.455
# 6     7     amar    BE  65.84   19  8.034
# 7     8    amita    BE  68.83   23  8.333
# 8     9     amol    TE  57.25   20  7.175
# 9    10    anmol    BE  79.16   21  9.366

# %%
data=['M','M','M','M','F','F','M','F','M','M']
data
# Out:
# ['M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'M']

# %%
df['gender']=data

# %%
df
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  57.27   22  7.227      M
# 1     2     amit    TE  60.27   21  7.527      M
# 2     3   aniket    BE  77.38   19  9.238      M
# 3     4  ajinkya    TE  70.16   20  8.516      M
# 4     5     asha    TE  63.78   20  7.878      F
# 5     6   ayesha    BE  50.05   20  6.505      F
# 6     7     amar    BE  65.84   19  8.084      M
# 7     8    amita    BE  68.83   23  8.383      F
# 8     9     amol    TE  57.25   20  7.225      M
# 9    10    anmol    BE  79.16   21  9.416      M

# %%
merge
join :- #inner join and # outer join
append
concat

# %%
df.drop(['cgpa','gender'],axis=1,inplace=True)
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.27   22
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 5     6   ayesha    BE  50.05   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 8     9     amol    TE  57.25   20
# 9    10    anmol    BE  79.16   21

# %%
nwedf=pd.DataFrame({
    'roll':range(1,11),
    'cgpa':df['marks']/10+1.5,
    'gender':data
})
nwedf
# Out:
#    roll   cgpa gender
# 0     1  7.227      M
# 1     2  7.527      M
# 2     3  9.238      M
# 3     4  8.516      M
# 4     5  7.878      F
# 5     6  6.505      F
# 6     7  8.084      M
# 7     8  8.383      F
# 8     9  7.225      M
# 9    10  9.416      M

# %%
df.shape
# Out:
# (10, 5)

# %%
nwedf.shape
# Out:
# (10, 3)

# %%
df.merge(nwedf,on='roll',how='inner') #innner join
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  57.27   22  7.227      M
# 1     2     amit    TE  60.27   21  7.527      M
# 2     3   aniket    BE  77.38   19  9.238      M
# 3     4  ajinkya    TE  70.16   20  8.516      M
# 4     5     asha    TE  63.78   20  7.878      F
# 5     6   ayesha    BE  50.05   20  6.505      F
# 6     7     amar    BE  65.84   19  8.084      M
# 7     8    amita    BE  68.83   23  8.383      F
# 8     9     amol    TE  57.25   20  7.225      M
# 9    10    anmol    BE  79.16   21  9.416      M

# %% [markdown]
# ## Append or concat  // row wise whereas merge and join are used to merge column

# %%
df5= pd.read_csv('student5.csv')
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
df.append(df5, ignore_index= True)
# Out:
# C:\Users\Riya Pandey\AppData\Local\Temp\ipykernel_20420\3354878241.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df5, ignore_index= True)
#     roll     name class  marks  age
# 0      1     anil    TE  57.27   22
# 1      2     amit    TE  60.27   21
# 2      3   aniket    BE  77.38   19
# 3      4  ajinkya    TE  70.16   20
# 4      5     asha    TE  63.78   20
# 5      6   ayesha    BE  50.05   20
# 6      7     amar    BE  65.84   19
# 7      8    amita    BE  68.83   23
# 8      9     amol    TE  57.25   20
# 9     10    anmol    BE  79.16   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %%
pd.concat([df,df5], ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  57.27   22
# 1      2     amit    TE  60.27   21
# 2      3   aniket    BE  77.38   19
# 3      4  ajinkya    TE  70.16   20
# 4      5     asha    TE  63.78   20
# 5      6   ayesha    BE  50.05   20
# 6      7     amar    BE  65.84   19
# 7      8    amita    BE  68.83   23
# 8      9     amol    TE  57.25   20
# 9     10    anmol    BE  79.16   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# #### Grouping operations

# %%
gr=df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.27   22
# 1     2     amit    TE  60.27   21
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 8     9     amol    TE  57.25   20

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  77.38   19
# 5     6  ayesha    BE  50.05   20
# 6     7    amar    BE  65.84   19
# 7     8   amita    BE  68.83   23
# 9    10   anmol    BE  79.16   21

# %%
gr.agg(sum)
# Out:
#        roll   marks  age
# class
# BE       34  341.26  102
# TE       21  308.73  103

# %%
gr.agg(max)
# Out:
#        roll    name  marks  age
# class
# BE       10  ayesha  79.16   23
# TE        9    asha  70.16   22

# %%
import numpy as np

# %%
gr.agg(np.mean)
# Out:
#        roll   marks   age
# class
# BE      6.8  68.252  20.4
# TE      4.2  61.746  20.6

# %% [markdown]
# ### string functions

# %%
gr.mean()
# Out:
#        roll   marks   age
# class
# BE      6.8  68.252  20.4
# TE      4.2  61.746  20.6

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.isupper()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, dtype: bool

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
df['name'].str.isalpha()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: name, dtype: bool

# %%
df['name'].str.repeat(3)
# Out:
# 0             anilanilanil
# 1             amitamitamit
# 2       aniketaniketaniket
# 3    ajinkyaajinkyaajinkya
# 4             ashaashaasha
# 5       ayeshaayeshaayesha
# 6             amaramaramar
# 7          amitaamitaamita
# 8             amolamolamol
# 9          anmolanmolanmol
# Name: name, dtype: object

# %%
df['name'].str.strip()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
# boolean filtering

# %%
filt=df['marks']>60

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[filt]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 9    10    anmol    BE  79.16   21

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 9    10    anmol    BE  79.16   21

# %%
x=df[(df['marks']>60) & (df['class']== 'BE')]
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  77.38   19
# 6     7    amar    BE  65.84   19
# 7     8   amita    BE  68.83   23
# 9    10   anmol    BE  79.16   21

# %% [markdown]
# ## Data Export

# %%
x.to_csv('output.csv',index=False)
x
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0

# %% [markdown]
#  #### Assignmet

# %%
rf=pd.read_csv('cricket.csv')

# %%
rf
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %%
rf['name']
# Out:
# 0      Anil Dalpat
# 1     Rohan Kanhay
# 2    Avdhoot Dighe
# 3         Bahubali
# 4        Leeladhar
# 5        Pradyumna
# 6       Dinesh Roy
# 7       Parmeshwar
# 8      Ali Durrani
# 9     Litesh Singh
# Name: name, dtype: object

# %%
x=rf[rf['matches']>100]
x['name']
# Out:
# 0      Anil Dalpat
# 1     Rohan Kanhay
# 2    Avdhoot Dighe
# 4        Leeladhar
# 5        Pradyumna
# 6       Dinesh Roy
# 7       Parmeshwar
# Name: name, dtype: object

# %%
y=rf['name'].str.startswith('A')
rf[y]
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 8      9    Ali Durrani       55  2756       12       26          0

# %%
rf['name'].str.upper()
# Out:
# 0      ANIL DALPAT
# 1     ROHAN KANHAY
# 2    AVDHOOT DIGHE
# 3         BAHUBALI
# 4        LEELADHAR
# 5        PRADYUMNA
# 6       DINESH ROY
# 7       PARMESHWAR
# 8      ALI DURRANI
# 9     LITESH SINGH
# Name: name, dtype: object

# %%
rf['runs'].sum()
# Out:
# 48322

# %%
rf['name']=rf['name'].str.upper()
rf
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    ANIL DALPAT      122  6755       56       12          0
# 1      2   ROHAN KANHAY      144  1256       76      178          0
# 2      3  AVDHOOT DIGHE      265  8954      120        0          0
# 3      4       BAHUBALI       10   756        6       11          3
# 4      5      LEELADHAR      234  2866      105      376          0
# 5      6      PRADYUMNA      177  5877       47      122          0
# 6      7     DINESH ROY      211  8537      112       16          0
# 7      8     PARMESHWAR      245  9466       53        0          0
# 8      9    ALI DURRANI       55  2756       12       26          0
# 9     10   LITESH SINGH       89  1099       46       49          0

# %%
rf=pd.read_csv('cricket.csv')

# %%
#7. find the name of wicketkeeper
rf[rf['stumpings']>0] ['name']
# Out:
# 3    BAHUBALI
# Name: name, dtype: object

# %%
# 8.find the average runs of the players who played 200+ players
rf[rf['matches']>200]['runs'].mean()
# Out:
# 7455.75

# %%
#9. Name of the player with highest runs per match
rpm=max(rf['runs']/rf['matches'])
rpm
# Out:
# 75.6

# %%
rf[rf['runs']/rf['matches']==rpm]['name']
# Out:
# 3    BAHUBALI
# Name: name, dtype: object

# %%
# 10. Find names of player with 50+ runs per match and 100+catched
temp=rf['runs']/rf['matches']>50
rf[temp & (rf['catches']>50)] ['name']
# Out:
# 0    ANIL DALPAT
# Name: name, dtype: object

# %% [markdown]
#  # Data cleaning

# %%
# remove irrelevant data
# Deduplicate your data
# Fix structural errors
# Deal with missing data
#fliter outliers
# Validate your data

# %%
import pandas as pd
df3=pd.read_csv('student3.csv')
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3['age'].mean()
# Out:
# 20.785714285714285

# %%
df3['marks '].mean()
# Out:
# 66.96714285714286

# %%
df3.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df3.columns=df3.columns.str.strip()
df3
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28   NaN
# 5      6   ayesha    BE    NaN  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66   NaN
# 11    11   surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 14    14   sachin   NaN  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df3['marks'].mean()
# Out:
# 66.96714285714286

# %%
df3[df3['name'].str.startswith('a')]
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28   NaN
# 5      6   ayesha    BE    NaN  20.0
# 6      7     amar    BE  65.34  19.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66   NaN

# %%
df3['name']=df3['name'].str.title()
df3
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    be  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3['class'].value_counts()
# Out:
# TE    9
# BE    4
# be    2
# Name: class, dtype: int64

# %%
df3['class']=df3['class'].str.upper()

# %%
df3['class'].value_counts()
# Out:
# TE    9
# BE    6
# Name: class, dtype: int64

# %%
df3.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df3[df3.duplicated()]
# Out:
#    roll  name class  marks   age
# 9     9  Amol    TE  56.75  20.0

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df3.count()
# Out:
# roll     15
# name     15
# class    14
# marks    13
# age      13
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    15 non-null     int64
#  1   name    15 non-null     object
#  2   class   14 non-null     object
#  3   marks   13 non-null     float64
#  4   age     13 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 720.0+ bytes

# %%
df3.isnull()
# Out:
#      roll   name  class  marks    age
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False   True
# 5   False  False  False   True  False
# 6   False  False  False  False  False
# 7   False  False  False  False  False
# 8   False  False  False  False  False
# 10  False  False  False  False   True
# 11  False  False  False   True  False
# 12  False  False  False  False  False
# 13  False  False  False  False  False
# 14  False  False   True  False  False
# 15  False  False  False  False  False

# %%
df3.isnull().sum()
# Out:
# roll     0
# name     0
# class    1
# marks    2
# age      2
# dtype: int64

# %%
df3.dropna()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3['marks']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df3['marks'].fillna(55)
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5     55.00
# 6     65.34
# 7     68.33
# 8     56.75
# 10    78.66
# 11    55.00
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df3['age'].fillna(20)
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['marks'].fillna(df3['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     67.753077
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 10    78.660000
# 11    67.753077
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks, dtype: float64

# %%
df3['age'].fillna(df3['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     21.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 10    21.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['class'].mode()[0]
# Out:
# 'TE'

# %%
df3['class'].fillna(df3['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     BE
# 8     TE
# 10    BE
# 11    TE
# 12    TE
# 13    BE
# 14    TE
# 15    TE
# Name: class, dtype: object

# %%
df3.fillna(method='pad')
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  63.28  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  20.0
# 11    11   Surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    BE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3.fillna(method='backfill')
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  65.34  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  23.0
# 11    11   Surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    TE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3.fillna(method='backfill', inplace=True)
df3.isnull().sum()
# Out:
# roll     0
# name     0
# class    0
# marks    0
# age      0
# dtype: int64

# %%
##LABEL ENCODING

# %%
#import the class 
from sklearn.preprocessing import LabelEncoder

# %%
#create the object
le = LabelEncoder()

# %%
#apply the methode
df3['name'] = le.fit_transform(df3['name'])

# %%
df3
# Out:
#     roll  name class  marks   age
# 0      1     6    TE  56.77  22.0
# 1      2     2    TE  59.77  21.0
# 2      3     5    BE  76.88  19.0
# 3      4     0    TE  69.66  20.0
# 4      5     8    TE  63.28  20.0
# 5      6     9    BE  65.34  20.0
# 6      7     1    BE  65.34  19.0
# 7      8     3    BE  68.33  23.0
# 8      9     4    TE  56.75  20.0
# 10    10     7    BE  78.66  23.0
# 11    11    14    TE  74.12  23.0
# 12    12    13    TE  74.12  22.0
# 13    13    12    BE  88.45  21.0
# 14    14    10    TE  59.33  21.0
# 15    15    11    TE  63.45  20.0

# %%
pd.get_dummies(df3)   #one Hot Encoding
# Out:
#     roll  name  marks   age  class_BE  class_TE
# 0      1     6  56.77  22.0         0         1
# 1      2     2  59.77  21.0         0         1
# 2      3     5  76.88  19.0         1         0
# 3      4     0  69.66  20.0         0         1
# 4      5     8  63.28  20.0         0         1
# 5      6     9  65.34  20.0         1         0
# 6      7     1  65.34  19.0         1         0
# 7      8     3  68.33  23.0         1         0
# 8      9     4  56.75  20.0         0         1
# 10    10     7  78.66  23.0         1         0
# 11    11    14  74.12  23.0         0         1
# 12    12    13  74.12  22.0         0         1
# 13    13    12  88.45  21.0         1         0
# 14    14    10  59.33  21.0         0         1
# 15    15    11  63.45  20.0         0         1

# %%
##Data SCalling

# %%
newdf3 = pd.DataFrame({
'A':[56,34,22,47,68,77,35,63,28,71],
'B':[345,675,778,654,778,654,675,346,775,234,223]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 newdf3 = pd.DataFrame({
#       2 'A':[56,34,22,47,68,77,35,63,28,71],
#       3 'B':[345,675,778,654,778,654,675,346,775,234,223]})
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %%
s
